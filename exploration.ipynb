# %%
# %matplotlib notebook
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
mlp = eval(str(np.load('../../Desktop/history_mlp_classical.npy')))

# %%
mlp_deep = eval(str(np.load('../../Desktop/history_mlp_classical_deep.npy')))

# %%
pb = eval(str(np.load('../../Desktop/history_poor_bayes1000.npy')))

# %%
pbd = eval(str(np.load('../../Desktop/history_poor_bayes_dropout.npy')))

# %%
mlp_fat = eval(str(np.load('../../Desktop/history_fat_mlp.npy')))

# %%
def plot_history(ds, names):
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.title('Loss value')
    for d, name in zip(ds, names):
        plt.plot(d['loss'], label=name + ' | train_loss')
        plt.plot(d['val_loss'], label=name + ' | val_loss')
    plt.legend()
    plt.subplot(1,2,2)
    plt.title('Accuracy')
    for d, name in zip(ds, names):
        plt.plot(d['acc'], label=name + ' | train_acc')
        plt.plot(d['val_acc'], label=name + ' | val_acc')
    plt.legend(loc=4)

# %%
plot_history([mlp, mlp_deep, pb, pbd], ['mlp', 'mlp_deep', 'bayes', 'drop_bayes'])
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_history([mlp_fat], ['mlp_fat'])
# Out:
# <img src="data:image/png;base64,...">
