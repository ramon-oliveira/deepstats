# %%
import pandas as pd

# %%
df = pd.read_csv('uncertainty_experiments.csv', sep=';')

# %%
df
# Out:
#                  Unnamed: 0  test_acc dataset             inside_labels  \
# 0   test_cifar_2labels_1_v1  0.957292   cifar                    [0, 1]
# 1   test_cifar_2labels_1_v2  0.954167   cifar                    [0, 1]
# 2   test_cifar_2labels_2_v1  0.894792   cifar                    [2, 7]
# 3   test_cifar_2labels_2_v2  0.912500   cifar                    [2, 7]
# 4   test_cifar_2lavels_3_v1  0.937500   cifar                    [8, 9]
# 5   test_cifar_2lavels_3_v2  0.934896   cifar                    [8, 9]
# 6   test_cifar_5labels_1_v1  0.822316   cifar           [0, 2, 4, 6, 8]
# 7   test_cifar_5labels_1_v2  0.808894   cifar           [0, 2, 4, 6, 8]
# 8   test_cifar_5labels_2_v1  0.791667   cifar           [1, 3, 5, 7, 9]
# 9   test_cifar_5labels_2_v2  0.796675   cifar           [1, 3, 5, 7, 9]
# 10  test_cifar_5labels_3_v1  0.792869   cifar           [0, 1, 2, 3, 4]
# 11  test_cifar_5labels_3_v2  0.793069   cifar           [0, 1, 2, 3, 4]
# ...
